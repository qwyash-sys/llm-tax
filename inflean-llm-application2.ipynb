# %%
# %pip install python-dotenv langchain-upstage
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.2/94.2 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 11.8 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 514.1/514.1 kB 11.4 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 11.1 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 11.0 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 8.7 MB/s eta 0:00:00a 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.5/67.5 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 7.6 MB/s eta 0:00:00
# ...

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# %pip install python-dotenv langchain-upstage

from langchain_upstage import ChatUpstage
llm = ChatUpstage()

llm.invoke("the weather in Korea?")

# %%
llm.invoke("the weather in Korea?")
# Out:
# AIMessage(content='I\'m unable to provide real-time weather information. However, I can tell you that South Korea has four distinct seasons:\n\n1. Spring (March to May): Mild and pleasant with occasional rain showers.\n2. Summer (June to August): Hot and humid, with temperatures often exceeding 30°C (86°F). The rainy season, known as the "Jangma," occurs during this time.\n3. Autumn (September to November): Cool and dry, with clear skies and beautiful foliage, especially in mountainous areas.\n4. Winter (December to February): Cold and dry, with temperatures often dropping below freezing. Snowfall is common in the northern parts of the country.\n\nFor the most accurate and up-to-date weather information, I recommend checking a reliable weather forecasting website or app.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 189, 'prompt_tokens': 14, 'total_tokens': 203, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_toke
# ...
