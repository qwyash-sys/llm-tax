# %% [markdown]
# # 1. 패키지 설치

# %%
# %pip install python-dotenv langchain langchain-upstage langchain-community langchain-text-splitters langchain-pinecone docx2txt
# Out:
# Requirement already satisfied: python-dotenv in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (1.2.2)
# Requirement already satisfied: langchain in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (1.3.11)
# Requirement already satisfied: langchain-upstage in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (0.7.7)
# Requirement already satisfied: langchain-community in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (0.4.2)
# Requirement already satisfied: langchain-text-splitters in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (1.1.2)
# Collecting langchain-pinecone
#   Downloading langchain_pinecone-0.2.13-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: docx2txt in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (0.9)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.7 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from langchain) (1.4.8)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.5 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from langchain) (1.2.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from langchain) (2.13.4)
# Requirement already satisfied: langchain-openai<2.0.0,>=1.0.2 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from langchain-upstage) (1.3.2)
# Requirement already satisfied: pypdf<7.0.0,>=4.2.0 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from langchain-upstage) (6.14.0)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from langchain-upstage) (2.34.2)
# Requirement already satisfied: tokenizers<0.21.0,>=0.20.0 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from langchain-upstage) (0.20.3)
# Requirement already satisfied: urllib3<3,>=2.6.3 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from langchain-upstage) (2.7.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from langchain-community) (3.14.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from langchain-community) (0.8.18)
# Requirement already satisfied: numpy>=1.26.2 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from langchain-community) (2.4.6)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from langchain-community) (2.14.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from langchain-community) (2.0.51)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from langchain-community) (9.1.4)
# Collecting pinecone<8.0.0,>=6.0.0 (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone)
#   Downloading pinecone-7.3.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: httpx>=0.28.0 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from langchain-pinecone) (0.28.1)
# Collecting simsimd>=5.9.11 (from langchain-pinecone)
#   Downloading simsimd-6.5.16-cp311-cp311-macosx_11_0_arm64.whl.metadata (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: typing_extensions>=4.4 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.15.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.2)
# Requirement already satisfied: anyio in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from httpx>=0.28.0->langchain-pinecone) (4.14.0)
# Requirement already satisfied: certifi in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from httpx>=0.28.0->langchain-pinecone) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from httpx>=0.28.0->langchain-pinecone) (1.0.9)
# Requirement already satisfied: idna in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from httpx>=0.28.0->langchain-pinecone) (3.18)
# Requirement already satisfied: h11>=0.16 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.28.0->langchain-pinecone) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (0.0.18)
# Requirement already satisfied: packaging>=23.2.0 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (24.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (0.16.2)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from langchain-openai<2.0.0,>=1.0.2->langchain-upstage) (2.43.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from langchain-openai<2.0.0,>=1.0.2->langchain-upstage) (0.13.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (3.7.0)
# Requirement already satisfied: orjson>=3.9.14 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: websockets>=15.0 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (15.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Collecting pinecone-plugin-assistant<2.0.0,>=1.6.0 (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone)
#   Downloading pinecone_plugin_assistant-1.8.0-py3-none-any.whl.metadata (30 kB)
# Collecting pinecone-plugin-interface<0.0.8,>=0.0.7 (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone)
#   Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.9.0.post0)
# Collecting aiohttp-retry<3.0.0,>=2.9.1 (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone)
#   Downloading aiohttp_retry-2.9.1-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from requests<3.0.0,>=2.31.0->langchain-upstage) (3.4.7)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from tokenizers<0.21.0,>=0.20.0->langchain-upstage) (0.36.2)
# Requirement already satisfied: filelock in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<0.21.0,>=0.20.0->langchain-upstage) (3.29.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<0.21.0,>=0.20.0->langchain-upstage) (2026.6.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<0.21.0,>=0.20.0->langchain-upstage) (1.5.1)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<0.21.0,>=0.20.0->langchain-upstage) (4.68.3)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.7->langchain) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.5->langchain) (1.12.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai<2.0.0,>=1.0.2->langchain-upstage) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai<2.0.0,>=1.0.2->langchain-upstage) (0.15.0)
# Requirement already satisfied: sniffio in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai<2.0.0,>=1.0.2->langchain-upstage) (1.3.1)
# Requirement already satisfied: six>=1.5 in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from python-dateutil>=2.5.3->pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.17.0)
# Requirement already satisfied: regex in /Users/nsj/.pyenv/versions/inflearn-llm-application2/lib/python3.11/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai<2.0.0,>=1.0.2->langchain-upstage) (2026.5.9)
# Downloading langchain_pinecone-0.2.13-py3-none-any.whl (26 kB)
# Downloading pinecone-7.3.0-py3-none-any.whl (587 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.6/587.6 kB 10.5 MB/s eta 0:00:00a 0:00:01
# Downloading simsimd-6.5.16-cp311-cp311-macosx_11_0_arm64.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 8.7 MB/s eta 0:00:00
# Downloading aiohttp_retry-2.9.1-py3-none-any.whl (10.0 kB)
# Downloading pinecone_plugin_assistant-1.8.0-py3-none-any.whl (259 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.3/259.3 kB 13.0 MB/s eta 0:00:00
# Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl (6.2 kB)
# Installing collected packages: simsimd, pinecone-plugin-interface, pinecone-plugin-assistant, pinecone, aiohttp-retry, langchain-pinecone
# Successfully installed aiohttp-retry-2.9.1 langchain-pinecone-0.2.13 pinecone-7.3.0 pinecone-plugin-assistant-1.8.0 pinecone-plugin-interface-0.0.7 simsimd-6.5.16
#
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 2. Knowledge Base 구성을 위한 데이터 생성
#
# - [RecursiveCharacterTextSplitter](https://python.langchain.com/v0.2/docs/how_to/recursive_text_splitter/)를 활용한 데이터 chunking
#     - split 된 데이터 chunk를 Large Language Model(LLM)에게 전달하면 토큰 절약 가능
#     - 비용 감소와 답변 생성시간 감소의 효과
#     - LangChain에서 다양한 [TextSplitter](https://python.langchain.com/v0.2/docs/how_to/#text-splitters)들을 제공
# - `chunk_size` 는 split 된 chunk의 최대 크기
# - `chunk_overlap`은 앞 뒤로 나뉘어진 chunk들이 얼마나 겹쳐도 되는지 지정

# %%
from langchain_community.document_loaders import Docx2txtLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,
    chunk_overlap=200,
)

loader = Docx2txtLoader('./tax.docx')
document_list = loader.load_and_split(text_splitter=text_splitter)

# %%
from dotenv import load_dotenv
from langchain_upstage import UpstageEmbeddings

# 환경변수를 불러옴
load_dotenv()

# Upstage 제공하는 Embedding Model을 활용해서 `chunk`를 vector화
embedding = UpstageEmbeddings(model="solar-embedding-1-large")

# %%
from langchain_pinecone import PineconeVectorStore

# 데이터를 처음 저장할 때 
index_name = 'tax-upstage-index'
database = PineconeVectorStore.from_documents(document_list, embedding, index_name=index_name)
database = PineconeVectorStore.from_existing_index(index_name=index_name, embedding=embedding)

)

# %% [markdown]
# # 3. 답변 생성을 위한 Retrieval
#
# - `Chroma`에 저장한 데이터를 유사도 검색(`similarity_search()`)를 활용해서 가져옴

# %%
query = '근로소득자 9천만원 세금 어케됨?'

# `k` 값을 조절해서 얼마나 많은 데이터를 불러올지 결정
retrieved_docs = database.similarity_search(query, k=3)

# %%
retrieved_docs
# Out:
# [Document(id='9775036e-f854-4b72-8815-4ea317549644', metadata={'source': './tax.docx'}, page_content='제5관 근로소득공제ㆍ연금소득공제 및 퇴직소득공제 <개정 2009. 12. 31.>\n\n\n\n제47조(근로소득공제) ①근로소득이 있는 거주자에 대해서는 해당 과세기간에 받는 총급여액에서 다음의 금액을 공제한다. 다만, 공제액이 2천만원을 초과하는 경우에는 2천만원을 공제한다. <개정 2012. 1. 1., 2014. 1. 1., 2019. 12. 31.>\n\n\n\n② 일용근로자에 대한 공제액은 제1항에도 불구하고 1일 15만원으로 한다.<개정 2018. 12. 31.>\n\n③ 근로소득이 있는 거주자의 해당 과세기간의 총급여액이 제1항 또는 제2항의 공제액에 미달하는 경우에는 그 총급여액을 공제액으로 한다.\n\n④ 제1항부터 제3항까지의 규정에 따른 공제를 “근로소득공제”라 한다.\n\n⑤ 제1항의 경우에 2인 이상으로부터 근로소득을 받는 사람(일용근로자는 제외한다)에 대하여는 그 근로소득의 합계액을 총급여액으로 하여 제1항에 따라 계산한 근로소득공제액을 총급여액에서 공제한다.<개정 2010. 12. 27.>\n\n⑥ 삭제<2010. 12. 27.>\n\n[전문개정 2009. 12. 31.]\n\n\n\n제47조의2(연금소득공제) ①연금소득이 있는 거주자에 대해서는 해당 과세기간에 받은 총연금액(분리과세연금소득은 제외하며, 이하 이 항에서 같다)에서 다음 표에 규정된 금액을 공제한다. 다만, 공제액이 900만원을 초과하는 경우에는 900만원을 공제한다. <개정 2013. 1. 1.>\n\n\n\n② 제1항에 따른 공제를 “연금소득공제”라 한다.\n\n[전문개정 2009. 12. 31.]\n\n\n\n제48조(퇴직소득공제) ① 퇴직소득이 있는 거주자에 대해서는 해당 과세기간의 퇴직소득금액에서 제1호의 구분에 따른 금액을 공제하고, 그 금액을 근속연수(1년 미만의 기간이 있는 경우에는 이를 1년으로 보며, 제22조제1항제1호의 경우에는 대통령령으로 정하는 방법에 따라 계산한 연수를 말한다. 이하 같다)로 나누고 12를 곱한 후의 금액(이하 이 항에서 “환산급여”라 한다)에서 제2호의 구분에 따른 금액을 공제한다. <개정 2014. 12. 23., 2022. 12. 31.>\n\n1. 근속연수에 따라 정한 다음의 금액\n\n\n\n2. 환산급여에 따라 정한 다음의 금액\n\n\n\n② 해당 과세기간의 퇴직소득금액이 제1항제1호에 따른 공제금액에 미달하는 경우에는 그 퇴직소득금액을 공제액으로 한다.<개정 2014. 12. 23.>\n\n③ 제1항과 제2항에 따른 공제를 “퇴직소득공제”라 한다.\n\n④ 퇴직소득공제의 계산 방법에 관하여 필요한 사항은 대통령령으로 정한다.<개정 2013. 1. 1.>\n\n⑤ 삭제<2013. 1. 1.>\n\n[전문개정 2009. 12. 31.]\n\n\n\n제49조 삭제 <2006. 12. 30.>\n\n\n\n제6관 종합소득공제 <개정 2009. 12. 31.>'),
#  Document(id='e5eb27e4-0f86-47d6-9995-18285d624c5d', metadata={'source': './tax.docx'}, page_content='제5관 근로소득공제ㆍ연금소득공제 및 퇴직소득공제 <개정 2009. 12. 31.>\n\n\n\n제47조(근로소득공제) ①근로소득이 있는 거주자에 대해서는 해당 과세기간에 받는 총급여액에서 다음의 금액을 공제한다. 다만, 공제액이 2천만원을 초과하는 경우에는 2천만원을 공제한다. <개정 2012. 1. 1., 2014. 1. 1., 2019. 12. 31.>\n\n\n\n② 일용근로자에 대한 공제액은 제1항에도 불구하고 1일 15만원으로 한다.<개정 2018. 12. 31.>\n\n③ 근로소득이 있는 거주자의 해당 과세기간의 총급여액이 제1항 또는 제2항의 공제액에 미달하는 경우에는 그 총급여액을 공제액으로 한다.\n\n④ 제1항부터 제3항까지의 규정에 따른 공제를 “근로소득공제”라 한다.\n\n⑤ 제1항의 경우에 2인 이상으로부터 근로소득을 받는 사람(일용근로자는 제외한다)에 대하여는 그 근로소득의 합계액을 총급여액으로 하여 제1항에 따라 계산한 근로소득공제액을 총급여액에서 공제한다.<개정 2010. 12. 27.>\n\n⑥ 삭제<2010. 12. 27.>\n\n[전문개정 2009. 12. 31.]\n\n\n\n제47조의2(연금소득공제) ①연금소득이 있는 거주자에 대해서는 해당 과세기간에 받은 총연금액(분리과세연금소득은 제외하며, 이하 이 항에서 같다)에서 다음 표에 규정된 금액을 공제한다. 다만, 공제액이 900만원을 초과하는 경우에는 900만원을 공제한다. <개정 2013. 1. 1.>\n\n\n\n② 제1항에 따른 공제를 “연금소득공제”라 한다.\n\n[전문개정 2009. 12. 31.]\n\n\n\n제48조(퇴직소득공제) ① 퇴직소득이 있는 거주자에 대해서는 해당 과세기간의 퇴직소득금액에서 제1호의 구분에 따른 금액을 공제하고, 그 금액을 근속연수(1년 미만의 기간이 있는 경우에는 이를 1년으로 보며, 제22조제1항제1호의 경우에는 대통령령으로 정하는 방법에 따라 계산한 연수를 말한다. 이하 같다)로 나누고 12를 곱한 후의 금액(이하 이 항에서 “환산급여”라 한다)에서 제2호의 구분에 따른 금액을 공제한다. <개정 2014. 12. 23., 2022. 12. 31.>\n\n1. 근속연수에 따라 정한 다음의 금액\n\n\n\n2. 환산급여에 따라 정한 다음의 금액\n\n\n\n② 해당 과세기간의 퇴직소득금액이 제1항제1호에 따른 공제금액에 미달하는 경우에는 그 퇴직소득금액을 공제액으로 한다.<개정 2014. 12. 23.>\n\n③ 제1항과 제2항에 따른 공제를 “퇴직소득공제”라 한다.\n\n④ 퇴직소득공제의 계산 방법에 관하여 필요한 사항은 대통령령으로 정한다.<개정 2013. 1. 1.>\n\n⑤ 삭제<2013. 1. 1.>\n\n[전문개정 2009. 12. 31.]\n\n\n\n제49조 삭제 <2006. 12. 30.>\n\n\n\n제6관 종합소득공제 <개정 2009. 12. 31.>'),
#  Document(id='8c467c4a-fd83-4df1-8bf5-fc68cfd351d3', metadata={'source': './tax.docx'}, page_content='⑥ 제1항과 제2항에 따라 결손금 및 이월결손금을 공제할 때 해당 과세기간에 결손금이 발생하고 이월결손금이 있는 경우에는 그 과세기간의 결손금을 먼저 소득금액에서 공제한다.\n\n[전문개정 2009. 12. 31.]\n\n\n\n제46조(채권 등에 대한 소득금액의 계산 특례) ① 거주자가 제16조제1항제1호ㆍ제2호ㆍ제5호 및 제6호에 해당하는 채권 또는 증권과 타인에게 양도가 가능한 증권으로서 대통령령으로 정하는 것(이하 이 조, 제133조의2 및 제156조의3에서 “채권등”이라 한다)의 발행법인으로부터 해당 채권등에서 발생하는 이자 또는 할인액(이하 이 조, 제133조의2 및 제156조의3에서 “이자등”이라 한다)을 지급[전환사채의 주식전환, 교환사채의 주식교환 및 신주인수권부사채의 신주인수권행사(신주 발행대금을 해당 신주인수권부사채로 납입하는 경우만 해당한다) 및 「자본시장과 금융투자업에 관한 법률」 제4조제7항제3호ㆍ제3호의2 및 제3호의3에 해당하는 채권등이 주식으로 전환ㆍ상환되는 경우를 포함한다. 이하 같다]받거나 해당 채권등을 매도(증여ㆍ변제 및 출자 등으로 채권등의 소유권 또는 이자소득의 수급권의 변동이 있는 경우와 매도를 위탁하거나 중개 또는 알선시키는 경우를 포함하되, 환매조건부채권매매거래 등 대통령령으로 정하는 경우는 제외한다. 이하 제133조의2에서 같다)하는 경우에는 거주자에게 그 보유기간별로 귀속되는 이자등 상당액을 해당 거주자의 제16조에 따른 이자소득으로 보아 소득금액을 계산한다. <개정 2010. 12. 27., 2012. 1. 1., 2020. 12. 29., 2024. 12. 31.>\n\n② 제1항을 적용할 때 해당 거주자가 해당 채권등을 보유한 기간을 대통령령으로 정하는 바에 따라 입증하지 못하는 경우에는 제133조의2제1항에 따른 원천징수기간의 이자등 상당액이 해당 거주자에게 귀속되는 것으로 보아 소득금액을 계산한다.<개정 2010. 12. 27.>\n\n③ 제1항 및 제2항에 따른 이자등 상당액의 계산방법과 그 밖에 필요한 사항은 대통령령으로 정한다.\n\n[전문개정 2009. 12. 31.]\n\n\n\n제46조의2(중도 해지로 인한 이자소득금액 계산의 특례) 종합소득과세표준 확정신고 후 예금 또는 신탁계약의 중도 해지로 이미 지난 과세기간에 속하는 이자소득금액이 감액된 경우 그 중도 해지일이 속하는 과세기간의 종합소득금액에 포함된 이자소득금액에서 그 감액된 이자소득금액을 뺄 수 있다. 다만, 「국세기본법」 제45조의2에 따라 과세표준 및 세액의 경정(更正)을 청구한 경우에는 그러하지 아니하다.\n\n[전문개정 2009. 12. 31.]\n\n\n\n제5관 근로소득공제ㆍ연금소득공제 및 퇴직소득공제 <개정 2009. 12. 31.>\n\n\n\n제47조(근로소득공제) ①근로소득이 있는 거주자에 대해서는 해당 과세기간에 받는 총급여액에서 다음의 금액을 공제한다. 다만, 공제액이 2천만원을 초과하는 경우에는 2천만원을 공제한다. <개정 2012. 1. 1., 2014. 1. 1., 2019. 12. 31.>')]

# %% [markdown]
# # 4. Augmentation을 위한 Prompt 활용
#
# - Retrieval된 데이터는 LangChain에서 제공하는 프롬프트(`"rlm/rag-prompt"`) 사용

# %%
from langchain_upstage import ChatUpstage

llm = ChatUpstage()

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages([
    ("human",
     "You are an assistant for question-answering tasks. "
     "Use the following retrieved context to answer the question. "
     "If you don't know the answer, just say that you don't know. "
     "Use three sentences maximum and keep the answer concise.\n\n"
     "Question: {question}\nContext: {context}\nAnswer:")
])

# %% [markdown]
# # 5. 답변 생성
#
# - [RetrievalQA](https://docs.smith.langchain.com/old/cookbook/hub-examples/retrieval-qa-chain)를 통해 LLM에 전달
#     - `RetrievalQA`는 [create_retrieval_chain](https://python.langchain.com/v0.2/docs/how_to/qa_sources/#using-create_retrieval_chain)으로 대체됨
#     - 실제 ChatBot 구현 시 `create_retrieval_chain`으로 변경하는 과정을 볼 수 있음

# %%
from langchain_classic.chains import RetrievalQA

qa_chain = RetrievalQA.from_chain_type(
    llm,
    retriever=database.as_retriever(),
    chain_type_kwargs={"prompt": prompt}
)

# %%
ai_message = qa_chain({"query": query})

# %%
# 강의에서는 위처럼 진행하지만 업데이트된 LangChain 문법은 `.invoke()` 활용을 권장

# %%
ai_message
# Out:
# {'query': '근로소득자 9천만원 세금 어케됨?',
#  'result': '근로소득자 9천만원의 세금 계산은 근로소득공제액을 고려해야 합니다. 근로소득공제액은 총급여액에서 공제하며, 공제액이 2천만원을 초과하지 않는 한 총급여액만큼 공제할 수 있습니다. 따라서 9천만원의 총급여액에서 2천만원을 공제한 7천만원이 근로소득금액이 됩니다. 이후 세율과 누진공제액을 적용하여 세금을 계산해야 합니다. 자세한 세금 계산은 국세청 홈택스를 통해 확인할 수 있습니다.'}
